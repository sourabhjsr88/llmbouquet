# %% [markdown]
# <a href="https://colab.research.google.com/github/sourabhjsr88/llmbouquet/blob/test/Playing_with_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Playing with Transformer from Huggingface
#
# Google colab comes with preinstalled torch & tensorflow. If you are not using colab you will have to install those.

# %%
# !pip install transformers datasets
# !pip install torch
# !pip install tensorflow
# !pip install sentencepiece
# !pip install sacremoses
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 19.9 MB/s eta 0:00:00
# ...
